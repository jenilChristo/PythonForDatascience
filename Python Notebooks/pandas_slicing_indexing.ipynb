# %% [markdown]
# <h2 style = "color : Brown">Case Study - Sales Data </h2>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
# All imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Displays pandas float values in 2 decimals
pd.options.display.float_format = '{:,.2f}'.format

# %%
sales = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/sales.xlsx')
sales.head(5)
# Out:
#    Market           Region  No_of_Orders     Profit     Sales
# 0  Africa   Western Africa           251 -12,901.51 78,476.06
# 1  Africa  Southern Africa            85  11,768.58 51,319.50
# 2  Africa     North Africa           182  21,643.08 86,698.89
# 3  Africa   Eastern Africa           110   8,013.04 44,182.60
# 4  Africa   Central Africa           103  15,606.30 61,689.99

# %%
sales.loc[:,["Region", "Profit"]]
# Out:
#                Region     Profit
# 0      Western Africa -12,901.51
# 1     Southern Africa  11,768.58
# 2        North Africa  21,643.08
# 3      Eastern Africa   8,013.04
# 4      Central Africa  15,606.30
# 5        Western Asia -16,766.90
# 6       Southern Asia  67,998.76
# 7   Southeastern Asia  20,948.84
# 8             Oceania  54,734.02
# 9        Eastern Asia  72,805.10
# 10       Central Asia  -2,649.76
# 11     Western Europe  82,091.27
# 12    Southern Europe  18,911.49
# 13    Northern Europe  43,237.44
# 14     Eastern Europe  25,050.69
# 15      South America  12,377.59
# 16    Central America  74,679.54
# 17          Caribbean  13,529.59
# 18         Western US  44,303.65
# 19        Southern US  19,991.83
# 20         Eastern US  47,462.04
# 21         Central US  33,697.43
# 22             Canada   7,246.62

# %%
sales.iloc[1,2]
# Out:
# 85

# %%
sales[["Region", "Market"]]
# Out:
#                Region        Market
# 0      Western Africa        Africa
# 1     Southern Africa        Africa
# 2        North Africa        Africa
# 3      Eastern Africa        Africa
# 4      Central Africa        Africa
# 5        Western Asia  Asia Pacific
# 6       Southern Asia  Asia Pacific
# 7   Southeastern Asia  Asia Pacific
# 8             Oceania  Asia Pacific
# 9        Eastern Asia  Asia Pacific
# 10       Central Asia  Asia Pacific
# 11     Western Europe        Europe
# 12    Southern Europe        Europe
# 13    Northern Europe        Europe
# 14     Eastern Europe        Europe
# 15      South America         LATAM
# 16    Central America         LATAM
# 17          Caribbean         LATAM
# 18         Western US          USCA
# 19        Southern US          USCA
# 20         Eastern US          USCA
# 21         Central US          USCA
# 22             Canada          USCA

# %% [markdown]
# ##### Sales and Profit data is read in dataframe "sales"

# %%
# Read file and set 2nd column as index

sales = pd.read_excel('sales.xlsx', index_col = [1])
sales
# Out:
#                          Market  No_of_Orders     Profit      Sales
# Region
# Western Africa           Africa           251 -12,901.51  78,476.06
# Southern Africa          Africa            85  11,768.58  51,319.50
# North Africa             Africa           182  21,643.08  86,698.89
# Eastern Africa           Africa           110   8,013.04  44,182.60
# Central Africa           Africa           103  15,606.30  61,689.99
# Western Asia       Asia Pacific           382 -16,766.90 124,312.24
# Southern Asia      Asia Pacific           469  67,998.76 351,806.60
# Southeastern Asia  Asia Pacific           533  20,948.84 329,751.38
# Oceania            Asia Pacific           646  54,734.02 408,002.98
# Eastern Asia       Asia Pacific           414  72,805.10 315,390.77
# %% [markdown]
# <h4 style = "color : Sky blue"> Example - 2 (Row Indexing)</h4>
#
# ##### Display data for "Southern Asia"
#
# loc accessor takes row index and column index

# %%
sales.loc["Southern Asia"]
# Out:
# Market          Asia Pacific
# No_of_Orders             469
# Profit             67,998.76
# Sales             351,806.60
# Name: Southern Asia, dtype: object

# %% [markdown]
# ##### Display Sales data for "Southern Asia"

# %%
sales.loc["Southern Asia", "Sales"]
# Out:
# 351806.6

# %% [markdown]
# ##### Display data for "Southern Asia"
#
# iloc accessor takes row number and column number

# %%
sales.iloc[6]
# Out:
# Market          Asia Pacific
# No_of_Orders             469
# Profit             67,998.76
# Sales             351,806.60
# Name: Southern Asia, dtype: object

# %%
sales.iloc[6,3]
# Out:
# 351806.6

# %% [markdown]
# <h4 style = "color : Sky blue"> Example - 3 (Slicing)</h4>
#
# ##### Display data for  Market, Sales and Profit

# %%
sales.loc[:, ["Market", "Sales", "Profit"]].head()
# Out:
#                  Market     Sales     Profit
# Region
# Western Africa   Africa 78,476.06 -12,901.51
# Southern Africa  Africa 51,319.50  11,768.58
# North Africa     Africa 86,698.89  21,643.08
# Eastern Africa   Africa 44,182.60   8,013.04
# Central Africa   Africa 61,689.99  15,606.30

# %%
sales.iloc[:, [0,3,2] ].head()
# Out:
#                  Market     Sales     Profit
# Region
# Western Africa   Africa 78,476.06 -12,901.51
# Southern Africa  Africa 51,319.50  11,768.58
# North Africa     Africa 86,698.89  21,643.08
# Eastern Africa   Africa 44,182.60   8,013.04
# Central Africa   Africa 61,689.99  15,606.30

# %% [markdown]
# ##### Display data for Western Africa Southern Africa and North Africa

# %%
sales.loc[["Western Africa", "Southern Africa", "North Africa"] ,:]
# Out:
#                  Market  No_of_Orders     Profit     Sales
# Region
# Western Africa   Africa           251 -12,901.51 78,476.06
# Southern Africa  Africa            85  11,768.58 51,319.50
# North Africa     Africa           182  21,643.08 86,698.89

# %%
sales.iloc[0:3, :]
# Out:
#                  Market  No_of_Orders     Profit     Sales
# Region
# Western Africa   Africa           251 -12,901.51 78,476.06
# Southern Africa  Africa            85  11,768.58 51,319.50
# North Africa     Africa           182  21,643.08 86,698.89

# %% [markdown]
# ##### Display Sales and Profit data for Western Africa Southern Africa and North Africa

# %%
sales.loc[["Western Africa", "Southern Africa", "North Africa"] , ["Sales", "Profit"]]
# Out:
#                     Sales     Profit
# Region
# Western Africa  78,476.06 -12,901.51
# Southern Africa 51,319.50  11,768.58
# North Africa    86,698.89  21,643.08

# %%
sales.iloc[0:3, 2:4]
# Out:
#    No_of_Orders     Profit
# 0           251 -12,901.51
# 1            85  11,768.58
# 2           182  21,643.08

# %%
import pandas as pd
df = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv')
df_2 = df.loc[ 2::2, :]
print(df_2.head(20))
# Out:
#     X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
#
# 155  7  4   aug  sun 94.80 108.30 647.10 17.00 16.40  47  1.30  0.00  1.56
# 156  2  4   sep  sat 93.40 145.40 721.40  8.10 28.60  27  2.20  0.00  1.61
# 157  2  2   aug  wed 92.10 111.20 654.10  9.60 18.40  45  3.60  0.00  1.63
# 158  2  4   aug  wed 92.10 111.20 654.10  9.60 20.50  35  4.00  0.00  1.64

# %% [markdown]
# ### Optional Examples
#
# The examples given below are good to know but not essential to achieve the objective of this session. You can go through them at your own pace.

# %% [markdown]
# <h4 style = "color : Sky blue"> Example - 5 (Transformation)</h4>
#
# ##### Replace the sales values in the form of thousands
#
# Context: Some time you might want to modify columns to make them more readable. For instance, the sales column in the given data set has six digits, followed by two decimal places. You might want to make it more readable. You can convert the actual sales number to a number in thousands and make it a round figure.
#
# eg. 300000 - 300K
#
# You can use the .floordiv function to achieve the transformation explained above. You can read more about the .floordiv method [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.floordiv.html).

# %%
sales.Sales = sales.Sales.floordiv(1000)

sales.head()
# Out:
#                  Market  No_of_Orders     Profit  Sales
# Region
# Western Africa   Africa           251 -12,901.51  78.00
# Southern Africa  Africa            85  11,768.58  51.00
# North Africa     Africa           182  21,643.08  86.00
# Eastern Africa   Africa           110   8,013.04  44.00
# Central Africa   Africa           103  15,606.30  61.00

# %%
sales.rename(columns={'Sales': 'Sales in Thousands'}, inplace=True)
sales.head()
# Out:
#                  Market  No_of_Orders     Profit  Sales in Thousands
# Region
# Western Africa   Africa           251 -12,901.51               78.00
# Southern Africa  Africa            85  11,768.58               51.00
# North Africa     Africa           182  21,643.08               86.00
# Eastern Africa   Africa           110   8,013.04               44.00
# Central Africa   Africa           103  15,606.30               61.00

# %% [markdown]
# ##### Replace values in Profit percent of total

# %%
sales.head()
# Out:
#                  Market  No_of_Orders     Profit  Sales in Thousands
# Region
# Western Africa   Africa           251 -12,901.51               78.00
# Southern Africa  Africa            85  11,768.58               51.00
# North Africa     Africa           182  21,643.08               86.00
# Eastern Africa   Africa           110   8,013.04               44.00
# Central Africa   Africa           103  15,606.30               61.00

# %%
#sales['Profit']
total_sum = sales.Profit.sum()
sales['Profit % of Total'] = sales.Profit.apply(lambda x: x/total_sum*100)

sales.head()
# Out:
#                  Market  No_of_Orders     Profit  Sales in Thousands  \
# Region
# Western Africa   Africa           251 -12,901.51               78.00
# Southern Africa  Africa            85  11,768.58               51.00
# North Africa     Africa           182  21,643.08               86.00
# Eastern Africa   Africa           110   8,013.04               44.00
# Central Africa   Africa           103  15,606.30               61.00
#
#                  Profit % of Total
# Region
# Western Africa               -1.94
# Southern Africa               1.77
# North Africa                  3.26
# Eastern Africa                1.21
# Central Africa                2.35

# %% [markdown]
# ##### Replace negative Profits with NAN

# %%
sales.loc[sales['Profit']<0, 'Profit'] = np.nan
sales.head()
# Out:
#                  Market  No_of_Orders    Profit     Sales
# Region
# Western Africa   Africa           251       nan 78,476.06
# Southern Africa  Africa            85 11,768.58 51,319.50
# North Africa     Africa           182 21,643.08 86,698.89
# Eastern Africa   Africa           110  8,013.04 44,182.60
# Central Africa   Africa           103 15,606.30 61,689.99
