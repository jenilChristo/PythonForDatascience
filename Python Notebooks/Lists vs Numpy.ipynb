# %%
heights = [72,73,75,84,70,77]

# %%
heights * 2.54
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-497196be6adf> in <module>
# ----> 1 heights * 2.54
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
import numpy as np

# %%
np_heights = np.array(heights)

# %%
np_heights
# Out:
# array([72, 73, 75, 84, 70, 77])

# %%
type(np_heights)
# Out:
# numpy.ndarray

# %%
np_heights * 2.54
# Out:
# array([182.88, 185.42, 190.5 , 213.36, 177.8 , 195.58])

# %% [markdown]
# **Numpy comes with its own set of methods and operations**

# %%
list_1 = [1,2,3]
list_2 = [5,6,7]

list_1 + list_2
# Out:
# [1, 2, 3, 5, 6, 7]

# %%
np_list1 = np.array(list_1)
np_list2 = np.array(list_2)

np_list1 + np_list2
# Out:
# array([ 6,  8, 10])

# %%
type(np_list1)
# Out:
# numpy.ndarray
