# %%
list_1 = [i for i in range(1000000)]
list_2 = [j**2 for j in range(1000000)]

# %%
import time 

t1 = time.time()

multiplied_list = list(map(lambda x,y: x*y, list_1, list_2))

t2 = time.time()

print(t2-t1)
# Out:
# 0.2314455509185791

# %%
import numpy as np
array_1 = np.array(list_1)
array_2 = np.array(list_2)

# %%
t1 = time.time()

multiplied = array_1 * array_2
t2 = time.time()

print(t2 - t1)
# Out:
# 0.03173184394836426

# %%
import time 
import numpy as np

list_1 = [i for i in range(10000000)]
list_2 = [j**2 for j in range(10000000)]

t1 = time.time()

multiplied_list = list(map(lambda x,y: x*y, list_1, list_2))

t2 = time.time()

list_time  = t2-t1
print(t2-t1)

array_1 = np.array(list_1)
array_2 = np.array(list_2)

t1 = time.time()
multiplied = array_1 * array_2

t2 = time.time()
numpy_time = t2 - t1

print(t2 - t1)

print("The ratio of time taken {}", list_time//numpy_time)
# Out:
# 1.5661723613739014
# 0.0598909854888916
# The ratio of time taken {} 26.0
